# %%
import pandas as pd
import numpy as np
data = pd.read_csv("Iris.csv")

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.columns.values
# Out:
# array(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm',
#        'PetalWidthCm', 'Species'], dtype=object)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
values_to_replace2 = [4.7,4.6]
df.replace(values_to_replace2, pd.NA, inplace=True)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    6
# SepalWidthCm     0
# PetalLengthCm    8
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
avg_sl = df["SepalLengthCm"].mean(axis = 0)

# %%
df.SepalLengthCm.fillna(value=avg_sl, inplace=True)

# %%
avg_pl = df["PetalLengthCm"].mean()

# %%
df.PetalLengthCm.fillna(value=avg_pl, inplace=True)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df["SepalLengthCm"] =df["SepalLengthCm"].astype("int")

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm      int64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1              5           3.5            1.4           0.2  Iris-setosa
# 1   2              4           3.0            1.4           0.2  Iris-setosa
# 2   3              5           3.2            1.3           0.2  Iris-setosa
# 3   4              5           3.1            1.5           0.2  Iris-setosa
# 4   5              5           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn import preprocessing

# %%
scaler = preprocessing.MinMaxScaler()

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df['Species']= label_encoder.fit_transform(df['Species'])

# %%
df['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
df["Species"].dtype
# Out:
# dtype('int64')

# %%
x_scaled = scaler.fit_transform(df)

# %%
df_norm= pd.DataFrame(x_scaled)

# %%
df_norm.head()
# Out:
#           0         1         2         3         4    5
# 0  0.000000  0.333333  0.625000  0.067797  0.041667  0.0
# 1  0.006711  0.000000  0.416667  0.067797  0.041667  0.0
# 2  0.013423  0.333333  0.500000  0.050847  0.041667  0.0
# 3  0.020134  0.333333  0.458333  0.084746  0.041667  0.0
# 4  0.026846  0.333333  0.666667  0.067797  0.041667  0.0

# %%
df['Species'].unique()

features_df=df.drop(columns=['Species'])
enc = preprocessing.OneHotEncoder()
enc_df = pd.DataFrame(enc.fit_transform(df[['Species']]).todense())
df_encode = features_df.join(enc_df)
df_encode
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm    0    1  \
# 0      1              5           3.5            1.4           0.2  1.0  0.0
# 1      2              4           3.0            1.4           0.2  1.0  0.0
# 2      3              5           3.2            1.3           0.2  1.0  0.0
# 3      4              5           3.1            1.5           0.2  1.0  0.0
# 4      5              5           3.6            1.4           0.2  1.0  0.0
# ..   ...            ...           ...            ...           ...  ...  ...
# 145  146              6           3.0            5.2           2.3  0.0  0.0
# 146  147              6           2.5            5.0           1.9  0.0  0.0
# 147  148              6           3.0            5.2           2.0  0.0  0.0
# 148  149              6           3.4            5.4           2.3  0.0  0.0
# 149  150              5           3.0            5.1           1.8  0.0  0.0
#
#        2
# 0    0.0
# 1    0.0
# 2    0.0
# ...
